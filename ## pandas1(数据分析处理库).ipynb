# %%
import pandas as pd

# %%
df=pd.read_csv('./data/train.csv')       #格式：pd.read_csv('文件路径加带后缀的文件名')

# %%
df.head(6)      # .head(n)读取前n条数据
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # 上面的表格就是一个DataFrame结构

# %%
df.info()   # .info返回当前信息，读取
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
data={'country':['aaa','bbb','ccc'],'population':[12,43,56]}

# %%
frame=pd.DataFrame(data)

# %%
frame
# Out:
#   country  population
# 0     aaa          12
# 1     bbb          43
# 2     ccc          56

# %% [markdown]
# # 说明：要想建立一个表格，首先要构建一个字典，然后使用pd.DataFrame(字典名)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# country       3 non-null object
# population    3 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 128.0+ bytes

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
age = df['Age']
age[:5]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# # 如果想拿出来指定一列，只要df['列名字']

# %% [markdown]
# # ------------------------------------------------------------------------------------

# %% [markdown]
# # 在DateFrame中默认是最左边的数字序号作为索引，也可以自行设置索引值：
# # df = df.set_index('Name')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df=df.set_index('Name')

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...

# %% [markdown]
# # 由上表可以看出索引已经是以名字为索引了

# %%
df['Age'][:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
# Name: Age, dtype: float64

# %% [markdown]
# # 由上面的可以看出，索引已经变成了Name

# %%
age= df['Age']

# %% [markdown]
# # 根据索引寻找某个人的年龄

# %%
age['Allen, Mr. William Henry']
# Out:
# 35.0

# %% [markdown]
# # ------------------------------------------------------------------------------

# %%
age = age + 10
age[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                32.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    48.0
# Heikkinen, Miss. Laina                                 36.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           45.0
# Allen, Mr. William Henry                               45.0
# Name: Age, dtype: float64

# %% [markdown]
# # 上面对年龄进行了加法操作，乘法操作，减法操作等

# %% [markdown]
# # ------------------------------------------------------------------------------

# %%
age.mean()
# Out:
# 39.69911764705882

# %% [markdown]
# # 求平均值，df.mean()

# %% [markdown]
# # ------------------------------------------------------------------------------

# %%
age.max()
# Out:
# 90.0

# %%
age.min()
# Out:
# 10.42

# %% [markdown]
# # 计算最大值，最小值

# %% [markdown]
# # ------------------------------------------------------------------------------

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 非常重要************************************************

# %% [markdown]
# # df.describe()     进行统计，直接得到统计值，包括最大，最小，平均，方差等

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------
