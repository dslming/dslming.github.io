# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
import pandas as pd

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#orders.item_name.str.upper()[:5]

# %%
orders.item_name.str.contains('Chicken')[:2]
# Out:
# 0    False
# 1    False
# Name: item_name, dtype: bool

# %%
orders.choice_description.str.replace('[','').str.replace(']','')[:4]
# Out:
# 0           NaN
# 1    Clementine
# 2         Apple
# 3           NaN
# Name: choice_description, dtype: object

# %% [markdown]
# # 这样就把‘[’和']' 去掉了

# %%
orders.choice_description.str.replace('[\[\]]','')[:5]
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object
